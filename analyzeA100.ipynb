# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paths to your CSV files
file_paths = [
    'finalOutputNormal/A/100/summary_run1_seed1111.csv',
    'finalOutput/A/100/summary_run1.csv',
]

plt.figure(figsize=(10, 5))  # Set the size of the plot

# Loop through each file path
for i, file_path in enumerate(file_paths):
    df = pd.read_csv(file_path, sep=';')  # Read the file with the correct delimiter
    # Replace 'step_arrived' with the actual column name you wish to plot
    plt.plot(df['step_arrived'], label=f'Run {i + 1}')  

plt.title('Comparison of Vehicles Arrived Over Time')
plt.xlabel('Time (seconds)')
plt.ylabel('Number of Vehicles Arrived')
plt.legend()  # Add a legend to distinguish between runs
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
150.645341
# Out:
# Index(['step_arrived', 'step_collisions', 'step_duration', 'step_ended',
#        'step_halting', 'step_inserted', 'step_loaded', 'step_meanSpeed',
#        'step_meanSpeedRelative', 'step_meanTravelTime', 'step_meanWaitingTime',
#        'step_running', 'step_stopped', 'step_teleports', 'step_time',
#        'step_waiting'],
#       dtype='object')
# Statistics for step_meanTravelTime:
# Run 1:
# count    12000.000000
# mean        78.003989
# std          8.322727
# min         -1.000000
# 25%         77.440000
# 50%         79.170000
# 75%         80.100000
# max        104.000000
# Name: step_meanTravelTime, dtype: float64
#
# Run 2:
# count    12000.000000
# mean        76.074875
# std          7.892153
# min         -1.000000
# 25%         77.100000
# 50%         77.680000
# 75%         78.332500
# max         89.250000
# Name: step_meanTravelTime, dtype: float64
#
# Run 3:
# count    12000.000000
# mean        81.603306
# std          8.007746
# min         -1.000000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paths to your CSV files
file_paths = [
    'finalOutputNormal/A/75/summary_run1.csv',
    'finalOutputNormal/A/75/summary_run2.csv',
    'finalOutputNormal/A/75/summary_run3.csv',
    'finalOutputNormal/A/75/summary_run4.csv',
    'finalOutputNormal/A/75/summary_run5.csv',
    'finalOutputNormal/A/75/summary_run6.csv',
    'finalOutputNormal/A/75/summary_run7.csv',
    'finalOutputNormal/A/75/summary_run8.csv',
    'finalOutputNormal/A/75/summary_run9.csv',
    'finalOutputNormal/A/75/summary_run10.csv',
    'finalOutputNormal/A/75/summary_run11.csv',
    'finalOutputNormal/A/75/summary_run12.csv',
    'finalOutputNormal/A/75/summary_run13.csv',
    'finalOutputNormal/A/75/summary_run14.csv',
    'finalOutputNormal/A/75/summary_run15.csv',
    'finalOutputNormal/A/75/summary_run16.csv',
    'finalOutputNormal/A/75/summary_run17.csv',
    'finalOutputNormal/A/75/summary_run18.csv',
    'finalOutputNormal/A/75/summary_run19.csv',
    'finalOutputNormal/A/75/summary_run20.csv',
]


# Example for the first file
df_example = pd.read_csv(file_paths[0], sep=';')
print(df_example.columns)  # Print column names to identify key metrics

# Example metrics
metrics = ['step_meanTravelTime', 'step_meanSpeed']  # Replace with actual metrics

# Initialize a dictionary to store statistics
stats = {metric: [] for metric in metrics}

# Loop through files and calculate statistics
for file_path in file_paths:
    df = pd.read_csv(file_path, sep=';')
    for metric in metrics:
        stats[metric].append(df[metric].describe())

# Print statistics for each metric
for metric, values in stats.items():
    print(f"Statistics for {metric}:")
    for i, value in enumerate(values):
        print(f"Run {i + 1}:\n{value}\n")

        # Example visualization: Box plot for each metric
for metric in metrics:
    data = [pd.read_csv(file, sep=';')[metric] for file in file_paths]
    plt.figure()
    plt.boxplot(data)
    plt.title(f'Box Plot of {metric}')
    plt.xticks(range(1, len(file_paths) + 1), [f'Run {i+1}' for i in range(len(file_paths))])
    plt.ylabel(metric)
    plt.show()
# Out:
# Index(['step_arrived', 'step_collisions', 'step_duration', 'step_ended',
#        'step_halting', 'step_inserted', 'step_loaded', 'step_meanSpeed',
#        'step_meanSpeedRelative', 'step_meanTravelTime', 'step_meanWaitingTime',
#        'step_running', 'step_stopped', 'step_teleports', 'step_time',
#        'step_waiting'],
#       dtype='object')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 41
#      39 # Loop through files and calculate statistics
#      40 for file_path in file_paths:
# ---> 41     df = pd.read_csv(file_path, sep=';')
#      42     for metric in metrics:
#      43         stats[metric].append(df[metric].describe())
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paths to your CSV files
file_paths = [
    'finalOutput/A/75/emission_run1.csv',
    'finalOutput/A/75/emission_run2.csv',
    'finalOutput/A/75/emission_run3.csv',
    'finalOutput/A/75/emission_run4.csv',
    'finalOutput/A/75/emission_run5.csv',
    'finalOutput/A/75/emission_run6.csv',
    'finalOutput/A/75/emission_run7.csv',
    'finalOutput/A/75/emission_run8.csv',
    'finalOutput/A/75/emission_run9.csv',
    'finalOutput/A/75/emission_run10.csv',
    'finalOutput/A/75/emission_run11.csv',
    'finalOutput/A/75/emission_run12.csv',
    'finalOutput/A/75/emission_run13.csv',
    'finalOutput/A/75/emission_run14.csv',
    'finalOutput/A/75/emission_run15.csv',
    'finalOutput/A/75/emission_run16.csv',
    'finalOutput/A/75/emission_run17.csv',
    'finalOutput/A/75/emission_run18.csv',
    'finalOutput/A/75/emission_run19.csv',
    'finalOutput/A/75/emission_run20.csv',

]


# Example for the first file
df_example = pd.read_csv(file_paths[0], sep=';')
print(df_example.columns)  # Print column names to identify key metrics

# Example metrics
metrics = ['vehicle_CO2']  # Replace with actual metrics

# Initialize a dictionary to store statistics
stats = {metric: [] for metric in metrics}

# Loop through files and calculate statistics
for file_path in file_paths:
    df = pd.read_csv(file_path, sep=';')
    for metric in metrics:
        stats[metric].append(df[metric].describe())

# Print statistics for each metric
for metric, values in stats.items():
    print(f"Statistics for {metric}:")
    for i, value in enumerate(values):
        print(f"Run {i + 1}:\n{value}\n")

        # Example visualization: Box plot for each metric
for metric in metrics:
    data = [pd.read_csv(file, sep=';')[metric] for file in file_paths]
    plt.figure()
    plt.boxplot(data)
    plt.title(f'Box Plot of {metric}')
    plt.xticks(range(1, len(file_paths) + 1), [f'Run {i+1}' for i in range(len(file_paths))])
    plt.ylabel(metric)
    plt.show()
# Out:
# Index(['timestep_time', 'vehicle_CO', 'vehicle_CO2', 'vehicle_HC',
#        'vehicle_NOx', 'vehicle_PMx', 'vehicle_angle', 'vehicle_eclass',
#        'vehicle_electricity', 'vehicle_fuel', 'vehicle_id', 'vehicle_lane',
#        'vehicle_noise', 'vehicle_pos', 'vehicle_route', 'vehicle_speed',
#        'vehicle_type', 'vehicle_waiting', 'vehicle_x', 'vehicle_y'],
#       dtype='object')
# Statistics for vehicle_CO2:
# Run 1:
# count    56402.000000
# mean      2655.806254
# std       2338.722091
# min      -1900.190000
# 25%       1206.245000
# 50%       2000.500000
# 75%       4182.697500
# max      13418.210000
# Name: vehicle_CO2, dtype: float64
#
# Run 2:
# count    57579.000000
# mean      2643.361612
# std       2328.592096
# min      -1869.030000
# 25%       1191.420000
# 50%       1986.550000
# 75%       4164.665000
# max      12303.690000
# Name: vehicle_CO2, dtype: float64
#
# Run 3:
# count    58425.000000
# mean      2654.767466
# std       2341.770489
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paths to your CSV files
file_paths = [
    'finalOutput/A/100/summary_run1.csv',
    'finalOutput/A/100/summary_run2.csv',
    'finalOutput/A/100/summary_run3.csv',
    'finalOutput/A/100/summary_run4.csv',
    'finalOutput/A/100/summary_run5.csv',

]


# Example for the first file
df_example = pd.read_csv(file_paths[0], sep=';')
print(df_example.columns)  # Print column names to identify key metrics

# Example metrics
metrics = ['step_meanTravelTime']  # Replace with actual metrics

# Initialize a dictionary to store statistics
stats = {metric: [] for metric in metrics}

# Collecting data for boxplot
data_for_boxplot = []

for i, file_path in enumerate(file_paths):
    df = pd.read_csv(file_path, sep=';')
    metric_data = df[metric]

    # Calculating statistics
    median = metric_data.median()
    mode = metric_data.mode()[0]
    std_dev = metric_data.std()

    # Adding data for boxplot
    data_for_boxplot.append(metric_data)

        # Printing statistics
    print(f"Run {i + 1} Statistics:")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Standard Deviation: {std_dev}\n")

# Visualizing data with a boxplot
plt.figure()
plt.boxplot(data_for_boxplot)
plt.title(f'Box Plot of {metric}')
plt.xticks(range(1, len(file_paths) + 1), [f'Run {i+1}' for i in range(len(file_paths))])
plt.ylabel(metric)
plt.show()
# Out:
# Index(['step_arrived', 'step_collisions', 'step_duration', 'step_ended',
#        'step_halting', 'step_inserted', 'step_loaded', 'step_meanSpeed',
#        'step_meanSpeedRelative', 'step_meanTravelTime', 'step_meanWaitingTime',
#        'step_running', 'step_stopped', 'step_teleports', 'step_time',
#        'step_waiting'],
#       dtype='object')
# Run 1 Statistics:
# Median: 77.01
# Mode: 76.25
# Standard Deviation: 7.153788935566891
#
# Run 2 Statistics:
# Median: 75.83
# Mode: 75.43
# Standard Deviation: 7.2506717342474625
#
# Run 3 Statistics:
# Median: 73.66
# Mode: 73.42
# Standard Deviation: 6.411833786749816
#
# Run 4 Statistics:
# Median: 75.08
# Mode: 73.84
# Standard Deviation: 7.019762482123831
#
# Run 5 Statistics:
# Median: 73.17
# Mode: 72.93
# Standard Deviation: 6.0412536664782115

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paths to your CSV files
file_paths = [
    'finalOutput/A/100/summary_run1.csv',
    'finalOutput/A/100/summary_run2.csv',
    'finalOutput/A/100/summary_run3.csv',
    'finalOutput/A/100/summary_run4.csv',
    'finalOutput/A/100/summary_run5.csv',
    'finalOutputNormal/A/100/summary_run1_seed1111.csv'
]


# Example for the first file
df_example = pd.read_csv(file_paths[0], sep=';')
print(df_example.columns)  # Print column names to identify key metrics

# Example metrics
metrics = ['step_meanTravelTime']  # Replace with actual metrics

# Initialize a dictionary to store statistics
stats = {metric: [] for metric in metrics}

# Loop through files and calculate statistics
for file_path in file_paths:
    df = pd.read_csv(file_path, sep=';')
    for metric in metrics:
        stats[metric].append(df[metric].describe())

# Print statistics for each metric
for metric, values in stats.items():
    print(f"Statistics for {metric}:")
    for i, value in enumerate(values):
        print(f"Run {i + 1}:\n{value}")
        print("Additional Statistics:")
        print(f"Median: {column.median()}")
        print(f"Mode: {column.mode()[0]}")
        print(f"Standard Deviation: {column.std()}\n")

        # Example visualization: Box plot for each metric
for metric in metrics:
    data = [pd.read_csv(file, sep=';')[metric] for file in file_paths]
    plt.figure()
    plt.boxplot(data)
    plt.title(f'Box Plot of {metric}')
    plt.xticks(range(1, len(file_paths) + 1), [f'Run {i+1}' for i in range(len(file_paths))])
    plt.ylabel(metric)
    plt.show()
# Out:
# Index(['step_arrived', 'step_collisions', 'step_duration', 'step_ended',
#        'step_halting', 'step_inserted', 'step_loaded', 'step_meanSpeed',
#        'step_meanSpeedRelative', 'step_meanTravelTime', 'step_meanWaitingTime',
#        'step_running', 'step_stopped', 'step_teleports', 'step_time',
#        'step_waiting'],
#       dtype='object')
# Statistics for step_meanTravelTime:
# Run 1:
# count    12000.000000
# mean        76.789673
# std          7.153789
# min         -1.000000
# 25%         76.520000
# 50%         77.010000
# 75%         77.510000
# max         87.470000
# Name: step_meanTravelTime, dtype: float64
# Additional Statistics:
# Median: 141.0
# Mode: 161.0
# Standard Deviation: 101.5066492983071
#
# Run 2:
# count    12000.000000
# mean        76.108330
# std          7.250672
# min         -1.000000
# 25%         75.300000
# 50%         75.830000
# 75%         77.900000
# max         84.860000
# Name: step_meanTravelTime, dtype: float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paths to your CSV files
file_paths = [
    'finalOutput/A/75/summary_run1.csv',
    'finalOutput/A/75/summary_run2.csv',
    'finalOutput/A/75/summary_run3.csv',
    'finalOutput/A/75/summary_run4.csv',
    'finalOutput/A/75/summary_run5.csv',
    'finalOutput/A/75/summary_run6.csv',
    'finalOutput/A/75/summary_run7.csv',
    'finalOutput/A/75/summary_run8.csv',
    'finalOutput/A/75/summary_run9.csv',
    'finalOutput/A/75/summary_run10.csv',
    'finalOutput/A/75/summary_run11.csv',
    'finalOutput/A/75/summary_run12.csv',
    'finalOutput/A/75/summary_run13.csv',
    'finalOutput/A/75/summary_run14.csv',
    'finalOutput/A/75/summary_run15.csv',
    'finalOutput/A/75/summary_run16.csv',
    'finalOutput/A/75/summary_run17.csv',
    'finalOutput/A/75/summary_run18.csv',
    'finalOutput/A/75/summary_run19.csv',
    'finalOutput/A/75/summary_run20.csv',
]


# Example for the first file
df_example = pd.read_csv(file_paths[0], sep=';')
print(df_example.columns)  # Print column names to identify key metrics

# Example metrics
metrics = ['step_meanWaitingTime']  # Replace with actual metrics

# Initialize a dictionary to store statistics
stats = {metric: [] for metric in metrics}

# Collecting data for boxplot
data_for_boxplot = []

for i, file_path in enumerate(file_paths):
    df = pd.read_csv(file_path, sep=';')
    metric_data = df[metric]

    # Calculating statistics
    median = metric_data.median()
    mode = metric_data.mode()[0]
    std_dev = metric_data.std()

    # Adding data for boxplot
    data_for_boxplot.append(metric_data)

        # Printing statistics
    print(f"Run {i + 1} Statistics:")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Standard Deviation: {std_dev}\n")

# Visualizing data with a boxplot
plt.figure()
plt.boxplot(data_for_boxplot)
plt.title(f'Box Plot of {metric}')
plt.xticks(range(1, len(file_paths) + 1), [f'Run {i+1}' for i in range(len(file_paths))])
plt.ylabel(metric)
plt.show()
# Out:
# Index(['step_arrived', 'step_collisions', 'step_duration', 'step_ended',
#        'step_halting', 'step_inserted', 'step_loaded', 'step_meanSpeed',
#        'step_meanSpeedRelative', 'step_meanTravelTime', 'step_meanWaitingTime',
#        'step_running', 'step_stopped', 'step_teleports', 'step_time',
#        'step_waiting'],
#       dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 44
#      42 for i, file_path in enumerate(file_paths):
#      43     df = pd.read_csv(file_path, sep=';')
# ---> 44     metric_data = df[metric]
#      46     # Calculating statistics
#      47     median = metric_data.median()
#
# NameError: name 'metric' is not defined
